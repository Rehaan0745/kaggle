# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/rehaan0445/dataset/wdbc.names
# /kaggle/input/datasets/rehaan0445/dataset/wdbc.data

# %%
# ==========================================================
# Feedforward Neural Network (FFNN)
# Breast Cancer Wisconsin Diagnostic Dataset
# Input Layer  : 20 Features
# Hidden Layers: 5 Hidden Layers (10 Neurons each, ReLU)
# Output Layer : 1 Neuron (Sigmoid)
# ==========================================================

# Import Libraries
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# ==========================================================
# Check TensorFlow Version
# ==========================================================

print("TensorFlow Version :", tf.__version__)
print("Available GPUs :", tf.config.list_physical_devices('GPU'))

# ==========================================================
# Load Dataset
# ==========================================================

# Change the path if required
df = pd.read_csv(
    "/kaggle/input/datasets/rehaan0445/dataset/wdbc.data",
    header=None
)

# ==========================================================
# Display Dataset Information
# ==========================================================

print("\nFirst Five Rows")
print(df.head())

print("\nDataset Shape:", df.shape)

# ==========================================================
# Data Preprocessing
# ==========================================================

# First 20 features
X = df.iloc[:, 2:22].values

# Target Variable
# M = Malignant = 1
# B = Benign = 0

y = df.iloc[:, 1].map({'M': 1, 'B': 0}).values

# ==========================================================
# Train-Test Split
# ==========================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# ==========================================================
# Feature Scaling
# ==========================================================

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ==========================================================
# Build Feedforward Neural Network
# ==========================================================

model = Sequential([

    Input(shape=(20,)),

    Dense(10, activation='relu'),
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),

    Dense(1, activation='sigmoid')

])

# ==========================================================
# Compile Model
# ==========================================================

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ==========================================================
# Model Summary
# ==========================================================

print("\nModel Summary")
model.summary()

# ==========================================================
# Train Model
# ==========================================================

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.20,
    verbose=1
)

# ==========================================================
# Evaluate Model
# ==========================================================

loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

print("\n==============================")
print("Test Loss     :", loss)
print("Test Accuracy :", accuracy)
print("==============================")

# ==========================================================
# Predictions
# ==========================================================

y_pred_prob = model.predict(X_test)

y_pred = (y_pred_prob > 0.5).astype(int)

# ==========================================================
# Performance Metrics
# ==========================================================

print("\nAccuracy Score")
print(accuracy_score(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))

# ==========================================================
# Display Total Parameters
# ==========================================================

print("\nTotal Trainable Parameters:", model.count_params())
# Out:
# TensorFlow Version : 2.20.0
# Available GPUs : []
#
# First Five Rows
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 32 columns]
#
# Dataset Shape: (569, 32)
#
# Model Summary
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_42 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 661 (2.58 KB)
#  Trainable params: 661 (2.58 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4258 - loss: 0.7189 - val_accuracy: 0.6813 - val_loss: 0.6785
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7253 - loss: 0.6366 - val_accuracy: 0.7692 - val_loss: 0.6072
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8379 - loss: 0.5379 - val_accuracy: 0.8571 - val_loss: 0.5047
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8819 - loss: 0.4153 - val_accuracy: 0.8462 - val_loss: 0.3881
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8984 - loss: 0.2992 - val_accuracy: 0.8571 - val_loss: 0.3061
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9093 - loss: 0.2284 - val_accuracy: 0.8681 - val_loss: 0.2857
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9148 - loss: 0.1943 - val_accuracy: 0.8791 - val_loss: 0.2972
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9231 - loss: 0.1731 - val_accuracy: 0.8791 - val_loss: 0.2931
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9341 - loss: 0.1563 - val_accuracy: 0.8901 - val_loss: 0.2920
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9396 - loss: 0.1446 - val_accuracy: 0.8681 - val_loss: 0.3050
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9451 - loss: 0.1350 - val_accuracy: 0.9011 - val_loss: 0.2959
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.1292 - val_accuracy: 0.8901 - val_loss: 0.3020
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9588 - loss: 0.1223 - val_accuracy: 0.9121 - val_loss: 0.3035
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9560 - loss: 0.1154 - val_accuracy: 0.9121 - val_loss: 0.3067
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9588 - loss: 0.1074 - val_accuracy: 0.9011 - val_loss: 0.2729
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1040 - val_accuracy: 0.9121 - val_loss: 0.2944
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9670 - loss: 0.0990 - val_accuracy: 0.9121 - val_loss: 0.2962
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9698 - loss: 0.0906 - val_accuracy: 0.9341 - val_loss: 0.2742
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.0859 - val_accuracy: 0.9231 - val_loss: 0.2861
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9753 - loss: 0.0824 - val_accuracy: 0.9231 - val_loss: 0.2970
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9753 - loss: 0.0758 - val_accuracy: 0.9231 - val_loss: 0.2830
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9725 - loss: 0.0734 - val_accuracy: 0.9121 - val_loss: 0.2993
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9808 - loss: 0.0696 - val_accuracy: 0.9231 - val_loss: 0.2951
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9753 - loss: 0.0640 - val_accuracy: 0.9341 - val_loss: 0.2799
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9780 - loss: 0.0609 - val_accuracy: 0.9341 - val_loss: 0.2929
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.0579 - val_accuracy: 0.9231 - val_loss: 0.3077
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9835 - loss: 0.0547 - val_accuracy: 0.9341 - val_loss: 0.3030
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9808 - loss: 0.0528 - val_accuracy: 0.9341 - val_loss: 0.2918
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0489 - val_accuracy: 0.9341 - val_loss: 0.3225
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.0470 - val_accuracy: 0.9341 - val_loss: 0.3115
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0446 - val_accuracy: 0.9341 - val_loss: 0.3305
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0431 - val_accuracy: 0.9341 - val_loss: 0.3178
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0411 - val_accuracy: 0.9231 - val_loss: 0.3475
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0391 - val_accuracy: 0.9341 - val_loss: 0.3131
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0381 - val_accuracy: 0.9341 - val_loss: 0.3395
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0359 - val_accuracy: 0.9341 - val_loss: 0.3349
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0364 - val_accuracy: 0.9341 - val_loss: 0.3420
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0340 - val_accuracy: 0.9341 - val_loss: 0.3318
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9918 - loss: 0.0339 - val_accuracy: 0.9341 - val_loss: 0.3450
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0321 - val_accuracy: 0.9341 - val_loss: 0.3344
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0309 - val_accuracy: 0.9231 - val_loss: 0.3695
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0303 - val_accuracy: 0.9341 - val_loss: 0.3615
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0294 - val_accuracy: 0.9341 - val_loss: 0.3590
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0287 - val_accuracy: 0.9341 - val_loss: 0.3546
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0282 - val_accuracy: 0.9341 - val_loss: 0.3649
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0274 - val_accuracy: 0.9451 - val_loss: 0.3581
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0269 - val_accuracy: 0.9341 - val_loss: 0.3795
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0267 - val_accuracy: 0.9341 - val_loss: 0.3766
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0261 - val_accuracy: 0.9341 - val_loss: 0.3824
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0256 - val_accuracy: 0.9341 - val_loss: 0.3848
#
# ==============================
# Test Loss     : 0.27039065957069397
# Test Accuracy : 0.9473684430122375
# ==============================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Accuracy Score
# 0.9473684210526315
#
# Confusion Matrix
# [[70  2]
#  [ 4 38]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        72
#            1       0.95      0.90      0.93        42
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
#
# Total Trainable Parameters: 661

# %%
# ==========================================================
# FFNN with Batch Normalization, Dropout and Early Stopping
# Breast Cancer Wisconsin Diagnostic Dataset
# ==========================================================

# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# ==========================================================
# Load Dataset
# ==========================================================

df = pd.read_csv(
    "/kaggle/input/datasets/rehaan0445/dataset/wdbc.data",
    header=None
)

# ==========================================================
# Data Preprocessing
# ==========================================================

# Select first 20 features
X = df.iloc[:, 2:22].values

# Target Variable
y = df.iloc[:, 1].map({'M':1,'B':0}).values

# Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# Standardization

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ==========================================================
# Build Improved FFNN
# ==========================================================

model = Sequential([

    Input(shape=(20,)),

    Dense(10),
    BatchNormalization(),
    tf.keras.layers.ReLU(),
    Dropout(0.2),

    Dense(10),
    BatchNormalization(),
    tf.keras.layers.ReLU(),
    Dropout(0.2),

    Dense(10),
    BatchNormalization(),
    tf.keras.layers.ReLU(),
    Dropout(0.2),

    Dense(10),
    BatchNormalization(),
    tf.keras.layers.ReLU(),
    Dropout(0.2),

    Dense(10),
    BatchNormalization(),
    tf.keras.layers.ReLU(),
    Dropout(0.2),

    Dense(1, activation='sigmoid')

])

# ==========================================================
# Compile Model
# ==========================================================

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# ==========================================================
# Early Stopping
# ==========================================================

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# ==========================================================
# Train Model
# ==========================================================

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.20,
    callbacks=[early_stop],
    verbose=1
)

# ==========================================================
# Evaluate Model
# ==========================================================

loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

print("\nTest Loss :", loss)
print("Test Accuracy :", accuracy)

# ==========================================================
# Predictions
# ==========================================================

y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5).astype(int)

print("\nAccuracy Score")
print(accuracy_score(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))

# ==========================================================
# Plot Loss Curves
# ==========================================================

plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.show()

# ==========================================================
# Plot Accuracy Curves
# ==========================================================

plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6538 - loss: 0.6319 - val_accuracy: 0.6703 - val_loss: 0.6144
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6456 - loss: 0.6343 - val_accuracy: 0.6813 - val_loss: 0.6044
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6484 - loss: 0.6014 - val_accuracy: 0.6813 - val_loss: 0.5879
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6896 - loss: 0.5947 - val_accuracy: 0.7033 - val_loss: 0.5662
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6676 - loss: 0.5944 - val_accuracy: 0.7582 - val_loss: 0.5399
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7115 - loss: 0.5621 - val_accuracy: 0.7692 - val_loss: 0.5146
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7170 - loss: 0.5526 - val_accuracy: 0.7912 - val_loss: 0.4892
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6978 - loss: 0.5543 - val_accuracy: 0.8022 - val_loss: 0.4650
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.5132 - val_accuracy: 0.8022 - val_loss: 0.4445
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7060 - loss: 0.5394 - val_accuracy: 0.8571 - val_loss: 0.4223
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 0.5217 - val_accuracy: 0.8901 - val_loss: 0.4046
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7775 - loss: 0.4787 - val_accuracy: 0.8901 - val_loss: 0.3897
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7115 - loss: 0.5214 - val_accuracy: 0.9121 - val_loss: 0.3703
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7637 - loss: 0.4924 - val_accuracy: 0.9231 - val_loss: 0.3523
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7473 - loss: 0.4850 - val_accuracy: 0.9121 - val_loss: 0.3398
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7775 - loss: 0.4651 - val_accuracy: 0.9121 - val_loss: 0.3212
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8159 - loss: 0.4333 - val_accuracy: 0.9121 - val_loss: 0.3132
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7582 - loss: 0.4624 - val_accuracy: 0.9121 - val_loss: 0.3052
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7582 - loss: 0.4565 - val_accuracy: 0.9231 - val_loss: 0.3014
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7747 - loss: 0.4441 - val_accuracy: 0.9011 - val_loss: 0.2958
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7830 - loss: 0.4414 - val_accuracy: 0.9011 - val_loss: 0.2942
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8516 - loss: 0.3959 - val_accuracy: 0.9011 - val_loss: 0.2921
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8159 - loss: 0.4323 - val_accuracy: 0.9011 - val_loss: 0.2912
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8489 - loss: 0.3599 - val_accuracy: 0.9121 - val_loss: 0.2886
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8352 - loss: 0.3847 - val_accuracy: 0.9121 - val_loss: 0.2775
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8352 - loss: 0.3831 - val_accuracy: 0.9121 - val_loss: 0.2734
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8379 - loss: 0.3836 - val_accuracy: 0.9121 - val_loss: 0.2699
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8544 - loss: 0.3638 - val_accuracy: 0.9121 - val_loss: 0.2606
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8681 - loss: 0.3584 - val_accuracy: 0.9121 - val_loss: 0.2558
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8544 - loss: 0.3289 - val_accuracy: 0.9231 - val_loss: 0.2484
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8324 - loss: 0.3961 - val_accuracy: 0.9231 - val_loss: 0.2397
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8764 - loss: 0.3377 - val_accuracy: 0.9341 - val_loss: 0.2345
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8434 - loss: 0.3842 - val_accuracy: 0.9231 - val_loss: 0.2326
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8599 - loss: 0.3261 - val_accuracy: 0.9231 - val_loss: 0.2251
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8956 - loss: 0.3210 - val_accuracy: 0.9231 - val_loss: 0.2184
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8681 - loss: 0.3294 - val_accuracy: 0.9231 - val_loss: 0.2119
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9038 - loss: 0.2994 - val_accuracy: 0.9341 - val_loss: 0.2060
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8791 - loss: 0.2974 - val_accuracy: 0.9341 - val_loss: 0.2032
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8599 - loss: 0.3241 - val_accuracy: 0.9451 - val_loss: 0.2009
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8791 - loss: 0.3312 - val_accuracy: 0.9451 - val_loss: 0.1977
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8791 - loss: 0.2977 - val_accuracy: 0.9451 - val_loss: 0.1924
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8874 - loss: 0.3053 - val_accuracy: 0.9341 - val_loss: 0.1920
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8901 - loss: 0.3007 - val_accuracy: 0.9560 - val_loss: 0.1865
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8819 - loss: 0.3294 - val_accuracy: 0.9451 - val_loss: 0.1854
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8791 - loss: 0.3074 - val_accuracy: 0.9341 - val_loss: 0.1884
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8819 - loss: 0.3240 - val_accuracy: 0.9341 - val_loss: 0.1830
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8516 - loss: 0.3162 - val_accuracy: 0.9341 - val_loss: 0.1837
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8764 - loss: 0.3642 - val_accuracy: 0.9451 - val_loss: 0.1863
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8626 - loss: 0.3374 - val_accuracy: 0.9231 - val_loss: 0.1850
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8984 - loss: 0.2512 - val_accuracy: 0.9231 - val_loss: 0.1824
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9093 - loss: 0.2751 - val_accuracy: 0.9231 - val_loss: 0.1810
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8709 - loss: 0.3377 - val_accuracy: 0.9341 - val_loss: 0.1765
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9148 - loss: 0.2623 - val_accuracy: 0.9451 - val_loss: 0.1758
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8791 - loss: 0.2866 - val_accuracy: 0.9341 - val_loss: 0.1754
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8874 - loss: 0.2883 - val_accuracy: 0.9341 - val_loss: 0.1801
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9121 - loss: 0.2491 - val_accuracy: 0.9231 - val_loss: 0.1810
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8984 - loss: 0.2504 - val_accuracy: 0.9121 - val_loss: 0.1806
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8791 - loss: 0.3106 - val_accuracy: 0.9231 - val_loss: 0.1841
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9176 - loss: 0.2649 - val_accuracy: 0.9121 - val_loss: 0.1860
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8874 - loss: 0.2672 - val_accuracy: 0.9231 - val_loss: 0.1910
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9148 - loss: 0.2592 - val_accuracy: 0.9231 - val_loss: 0.1886
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8901 - loss: 0.2699 - val_accuracy: 0.9231 - val_loss: 0.1872
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9231 - loss: 0.2408 - val_accuracy: 0.9231 - val_loss: 0.1862
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8929 - loss: 0.2945 - val_accuracy: 0.9231 - val_loss: 0.1814
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 54.
#
# Test Loss : 0.17143353819847107
# Test Accuracy : 0.9298245906829834
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#
# Accuracy Score
# 0.9298245614035088
#
# Confusion Matrix
# [[67  5]
#  [ 3 39]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94        72
#            1       0.89      0.93      0.91        42
#
#     accuracy                           0.93       114
#    macro avg       0.92      0.93      0.93       114
# weighted avg       0.93      0.93      0.93       114

# %%
# ==========================================================
# Comparative Analysis
# Optimizers: SGD vs Adam
# Loss Functions: BCE vs MSE
# ==========================================================

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# ==========================================================
# Load Dataset
# ==========================================================

df = pd.read_csv(
    "/kaggle/input/datasets/rehaan0445/dataset/wdbc.data",
    header=None
)

# ==========================================================
# Data Preprocessing
# ==========================================================

X = df.iloc[:, 2:22].values
y = df.iloc[:, 1].map({'M':1,'B':0}).values

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ==========================================================
# Function to Build Model
# ==========================================================

def create_model():

    model = Sequential([

        Input(shape=(20,)),

        Dense(10),
        BatchNormalization(),
        tf.keras.layers.ReLU(),
        Dropout(0.2),

        Dense(10),
        BatchNormalization(),
        tf.keras.layers.ReLU(),
        Dropout(0.2),

        Dense(10),
        BatchNormalization(),
        tf.keras.layers.ReLU(),
        Dropout(0.2),

        Dense(10),
        BatchNormalization(),
        tf.keras.layers.ReLU(),
        Dropout(0.2),

        Dense(10),
        BatchNormalization(),
        tf.keras.layers.ReLU(),
        Dropout(0.2),

        Dense(1, activation='sigmoid')

    ])

    return model

# ==========================================================
# Configurations
# ==========================================================

configs = {

    "SGD + MSE": (
        tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
        "mse"
    ),

    "SGD + BCE": (
        tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
        "binary_crossentropy"
    ),

    "Adam + MSE": (
        tf.keras.optimizers.Adam(),
        "mse"
    ),

    "Adam + BCE": (
        tf.keras.optimizers.Adam(),
        "binary_crossentropy"
    )

}

results = []

# ==========================================================
# Train Each Configuration
# ==========================================================

for name, (optimizer, loss_function) in configs.items():

    print("\n======================================")
    print(name)
    print("======================================")

    model = create_model()

    model.compile(
        optimizer=optimizer,
        loss=loss_function,
        metrics=['accuracy']
    )

    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=0
    )

    history = model.fit(
        X_train,
        y_train,
        epochs=100,
        batch_size=16,
        validation_split=0.20,
        callbacks=[early_stop],
        verbose=0
    )

    # Test Accuracy
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

    # Epochs Used
    epochs_used = len(history.history['loss'])

    results.append([
        name,
        epochs_used,
        history.history['loss'][-1],
        history.history['val_loss'][-1],
        accuracy
    ])

# ==========================================================
# Comparative Table
# ==========================================================

results_df = pd.DataFrame(
    results,
    columns=[
        "Configuration",
        "Epochs to Converge",
        "Final Training Loss",
        "Final Validation Loss",
        "Final Test Accuracy"
    ]
)

print("\n================ Comparative Results ================\n")
print(results_df)

# Optional: Save Results
results_df.to_csv("comparison_results.csv", index=False)
# Out:
# ======================================
# SGD + MSE
# ======================================
#
# ======================================
# SGD + BCE
# ======================================
#
# ======================================
# Adam + MSE
# ======================================
#
# ======================================
# Adam + BCE
# ======================================
#
# ================ Comparative Results ================
#
#   Configuration  Epochs to Converge  Final Training Loss  \
# 0     SGD + MSE                  67             0.126125
# 1     SGD + BCE                  31             0.254735
# 2    Adam + MSE                  79             0.093275
# 3    Adam + BCE                 100             0.239065
#
#    Final Validation Loss  Final Test Accuracy
# 0               0.029873             0.947368
# 1               0.168357             0.938596
# 2               0.062217             0.947368
# 3               0.177469             0.929825

# %%
# ==========================================================
# ADVANCED PERFORMANCE EVALUATION
# Use the best trained model
# ==========================================================

import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
    accuracy_score
)

# ==========================================================
# Test Evaluation
# ==========================================================

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print("Test Loss :", test_loss)
print("Test Accuracy :", test_accuracy)

# ==========================================================
# Predictions
# ==========================================================

y_prob = model.predict(X_test)

y_pred = (y_prob > 0.5).astype(int)

# ==========================================================
# Accuracy Curves
# ==========================================================

plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")

plt.legend()

plt.show()

# ==========================================================
# Loss Curves
# ==========================================================

plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")

plt.legend()

plt.show()

# ==========================================================
# Confusion Matrix
# ==========================================================

cm = confusion_matrix(y_test, y_pred)

tn, fp, fn, tp = cm.ravel()

print("\nConfusion Matrix")
print(cm)

print("\nTrue Negatives :", tn)
print("False Positives:", fp)
print("False Negatives:", fn)
print("True Positives :", tp)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot(cmap='Blues')

plt.title("Confusion Matrix")

plt.show()

# ==========================================================
# Clinical Metrics
# ==========================================================

precision = precision_score(y_test, y_pred)

recall = recall_score(y_test, y_pred)

specificity = tn / (tn + fp)

f1 = f1_score(y_test, y_pred)

print("\n==============================")
print("Precision  :", precision)
print("Recall     :", recall)
print("Sensitivity:", recall)
print("Specificity:", specificity)
print("F1 Score   :", f1)
print("==============================")

# ==========================================================
# ROC Curve
# ==========================================================

fpr, tpr, threshold = roc_curve(y_test, y_prob)

auc_score = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(7,6))

plt.plot(fpr, tpr,
         label="AUC = {:.4f}".format(auc_score))

plt.plot([0,1],[0,1],'r--')

plt.xlabel("False Positive Rate")

plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()

print("\nROC-AUC Score :", auc_score)

# ==========================================================
# Summary
# ==========================================================

print("\n================ Final Results ================")

print("Accuracy     :", accuracy_score(y_test,y_pred))

print("Precision    :", precision)

print("Recall       :", recall)

print("Specificity  :", specificity)

print("F1 Score     :", f1)

print("ROC-AUC      :", auc_score)

print("==============================================")
# Out:
# Test Loss : 0.18180443346500397
# Test Accuracy : 0.9298245906829834
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Confusion Matrix
# [[67  5]
#  [ 3 39]]
#
# True Negatives : 67
# False Positives: 5
# False Negatives: 3
# True Positives : 39
# ==============================
# Precision  : 0.8863636363636364
# Recall     : 0.9285714285714286
# Sensitivity: 0.9285714285714286
# Specificity: 0.9305555555555556
# F1 Score   : 0.9069767441860465
# ==============================
# ROC-AUC Score : 0.9831349206349207
#
# ================ Final Results ================
# Accuracy     : 0.9298245614035088
# Precision    : 0.8863636363636364
# Recall       : 0.9285714285714286
# Specificity  : 0.9305555555555556
# F1 Score     : 0.9069767441860465
# ROC-AUC      : 0.9831349206349207
# ==============================================
